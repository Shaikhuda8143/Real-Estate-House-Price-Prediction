# %% [markdown]
# # Multiple Linear Regression Project On Real Estate

# %% [markdown]
# ## Project Overview:
# This project is to study the multiple linear realtionship between the given various features and the House price of unit area
# and also to build a model which predicts the house price of unit area.

# %% [markdown]
# ## Table Of Contents:
#  1. Linear Regression Definition and its types
#  2.Multiple Linear Regression

# %% [markdown]
# ## Linear Regression
# Linear Regression is a statistical technique which is used to find the linear relationship between dependent and one or more independent variables. This technique is applicable for Supervised learning Regression problems where we try to predict a continuous variable.
#
# Linear Regression can be further classified into two types
# - Simple and Multiple Linear Regression. In this project, I employ Simple Linear Regression technique where I have independent and dependent variable. It is the simplest form of Linear Regression where we fit a straight line to the data.

# %% [markdown]
# ## Multiple Linear Regression
# **MLR(Multiple Linear Regression)** tries to fit a regression line through a multidimensional space of data-points. In Multiple Linear Regression, the target variable (Y) is a linear combination of multiple predictor variables x 1, x 2, x 3, ...,x n.
#
# There is only one dependent variable and one independent variable is included in linear regression whereas in multiple regression, there are multiple independent variables that enable us to estimate the dependent variable y.
#
# **Multiple regression equation is derived by:**
#
# y = a + b 1×1+ b2×2+……+ bkxk
#
# where x1, x2, ….xk are the k independent variables and y is the dependent variable.

# %% [markdown]
# ## Software information
# I did this project using Jupyter notebook (Jupyter notebook server 6.4.5).

# %% [markdown]
# ## Python Libraries
# * Numpy – It provides a fast numerical array structure and operating functions.
#
# * pandas – It provides tools for data storage, manipulation and analysis tasks.
#
# * Scikit-Learn – The required machine learning library in Python.
#
# * Matplotlib – It is the basic plotting library in Python. It provides tools for making plots.
#
# * Seaborn - It is a plotting library in python. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ## Ordinary Least Square Method
# We can estimate the parameters of the model by minimizing the error in the model by minimizing D. Thus, we can find the regression line. This method of finding the parameters of the model and thus regression line is called Ordinary Least Square Method.
#
# In this project, I employ Multiple Linear Regression technique where I have one dependent variable and more than one independent variables.

# %% [markdown]
# ## Independent and dependent variables
# In this project, I refer Independent variable as Feature variable and Dependent variable as Target variable. These variables are also recognized by different names as follows: -
#
# Independent variable
#
# Independent variable is also called Input variable and is denoted by X. In practical applications, independent variable is also called Feature variable or Predictor variable. We can denote it as: -
#
# Independent or Input variable (X) = Feature variable = Predictor variable
#
# Dependent variable
#
# Dependent variable is also called Output variable and is denoted by y. Dependent variable is also called Target variable or Response variable. It can be denoted it as follows: -
#
# Dependent or Output variable (y) = Target variable = Response variable

# %% [markdown]
# ## Assumptions of Linear Regression
# The Linear Regression model is based on several assumptions which are as follows:-
#
# 1. Linear relationship
#
# 2. Multivariate normality
#
# 3. No or little multi-collinearity
#
# 4. No auto-correlation in error terms
#
# 5. Homoscedasticity

# %% [markdown]
# ## Data Description:
# * transaction date  --> purchase date
# * house age  ---> How many years built home
# * distance to the nearest MRT station --> distance from home to metro station
# * number of convenience stores  --> How many stores are near to home
# * latitude,longitude -->geographical representation
# * house price of unit area --> How much price of house per square meter

# %% [markdown]
# ## 1.Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2.Import Data

# %%
data=pd.read_csv("Real estate.csv")
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# ## 3.EDA(Exploratory Data Analysis)

# %%
#To view the dimensions of the data
data.shape
# Out:
# (414, 8)

# %%
#To check the null entries in the data
data.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
#View descriptive Statistics
data.describe().T
# Out:
#                                         count         mean          std  \
# No                                      414.0   207.500000   119.655756
# X1 transaction date                     414.0  2013.148971     0.281967
# X2 house age                            414.0    17.712560    11.392485
# X3 distance to the nearest MRT station  414.0  1083.885689  1262.109595
# X4 number of convenience stores         414.0     4.094203     2.945562
# X5 latitude                             414.0    24.969030     0.012410
# X6 longitude                            414.0   121.533361     0.015347
# Y house price of unit area              414.0    37.980193    13.606488
#
#                                                min          25%         50%  \
# No                                         1.00000   104.250000   207.50000
# X1 transaction date                     2012.66700  2012.917000  2013.16700
# X2 house age                               0.00000     9.025000    16.10000
# ...

# %%
#checking the data types
data.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
#Renaming the columns
data1=data.rename({'X1 transaction date':'x1_trans_date','X2 house age':'x2_h_age','X3 distance to the nearest MRT station':'x3_MRT_dist','X4 number of convenience stores':'x4_stores','X5 latitude':'x5_latitude','X6 longitude':'x6_longitude','Y house price of unit area':'house_price'},axis=1)
data1
# Out:
#       No  x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  x5_latitude  \
# 0      1       2012.917      32.0     84.87882         10     24.98298
# 1      2       2012.917      19.5    306.59470          9     24.98034
# 2      3       2013.583      13.3    561.98450          5     24.98746
# 3      4       2013.500      13.3    561.98450          5     24.98746
# 4      5       2012.833       5.0    390.56840          5     24.97937
# ..   ...            ...       ...          ...        ...          ...
# 409  410       2013.000      13.7   4082.01500          0     24.94155
# 410  411       2012.667       5.6     90.45606          9     24.97433
# 411  412       2013.250      18.8    390.96960          7     24.97923
# 412  413       2013.000       8.1    104.81010          5     24.96674
# 413  414       2013.500       6.5     90.45606          9     24.97433
#
#      x6_longitude  house_price
# 0       121.54024         37.9
# 1       121.53951         42.2
# ...

# %% [markdown]
# ## Inference:
#    >So my data is clean with no null entries and with no object datatypes

# %% [markdown]
# ## 4.Assumptions Check

# %% [markdown]
# ### 4.1 Linearity Test

# %%
sns.lmplot(x='x1_trans_date',y='house_price',data=data1)

# %%
sns.lmplot(x='x2_h_age',y='house_price',data=data1)

# %%
sns.lmplot(x='x3_MRT_dist',y='house_price',data=data1)

# %%
sns.lmplot(x='x4_stores',y='house_price',data=data1)

# %%
df=sns.lmplot(x='x5_latitude',y='house_price',data=data1)

# %%
sns.lmplot(x='x6_longitude',y='house_price',data=data1)

# %% [markdown]
# #### Linearity test failed

# %% [markdown]
# ### 4.2 Multi variate normality

# %%
from scipy import stats

# %%
stats.probplot(x=data1.x1_trans_date, dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(x=data1.x2_h_age, dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(x=data1.x3_MRT_dist, dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(x=data1.x4_stores, dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(x=data1.x5_latitude, dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(x=data1.x6_longitude, dist='norm', plot=plt)
plt.show()

# %% [markdown]
# #### Normality Test also Failed

# %% [markdown]
# ### 4.3 Multi Collinearity Test
# *Can be performed by using 2 techniques:*
#
# **4.3.1 Correlation Matrix**
#
# **4.3.2 Variance Inflation Factor[VIF].**

# %% [markdown]
# ### 4.3.1 Correlation Matrix

# %%
#To check how features are correalted
corr_matrix=data1.corr()
corr_matrix
# Out:
#                      No  x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  \
# No             1.000000      -0.048658 -0.032808    -0.013573  -0.012699
# x1_trans_date -0.048658       1.000000  0.017549     0.060880   0.009635
# x2_h_age      -0.032808       0.017549  1.000000     0.025622   0.049593
# x3_MRT_dist   -0.013573       0.060880  0.025622     1.000000  -0.602519
# x4_stores     -0.012699       0.009635  0.049593    -0.602519   1.000000
# x5_latitude   -0.010110       0.035058  0.054420    -0.591067   0.444143
# x6_longitude  -0.011059      -0.041082 -0.048520    -0.806317   0.449099
# house_price   -0.028587       0.087491 -0.210567    -0.673613   0.571005
#
#                x5_latitude  x6_longitude  house_price
# No               -0.010110     -0.011059    -0.028587
# x1_trans_date     0.035058     -0.041082     0.087491
# x2_h_age          0.054420     -0.048520    -0.210567
# x3_MRT_dist      -0.591067     -0.806317    -0.673613
# ...

# %% [markdown]
# ### Visual Exploratory Data Analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Interpretation of correlation coefficient
# **The correlation coefficient ranges from -1 to +1.**
#
# * When it is close to +1, this signifies that there is a strong positive correlation.
#
# * When it is clsoe to -1, it means that there is a strong negative correlation. We can see that X6 longitude and X3 distance to the nearest metro station are highly negatively correlated

# %%
sns.pairplot(data1)

# %% [markdown]
# ### 4.3.2 Varaince Inflation Factor
# * If VIF is greater than 10 then variables are said to be collinear
# * Checking collinearity for all independent variables

# %%
import statsmodels.formula.api as smf

# %%
rsq_x1= smf.ols(formula='x1_trans_date~x2_h_age+x3_MRT_dist+x4_stores+x5_latitude+x6_longitude',data=data1).fit().rsquared
vif_x1= 1/(1-rsq_x1)
rsq_x2=smf.ols(formula='x2_h_age~x1_trans_date+x3_MRT_dist+x4_stores+x5_latitude+x6_longitude',data=data1).fit().rsquared
vif_x2=1/(1-rsq_x2)
rsq_x3=smf.ols(formula='x3_MRT_dist~x1_trans_date+x2_h_age+x4_stores+x5_latitude+x6_longitude',data=data1).fit().rsquared
vif_x3=1/(1-rsq_x3)
rsq_x4=smf.ols(formula='x4_stores~x1_trans_date+x2_h_age+x3_MRT_dist+x5_latitude+x6_longitude',data=data1).fit().rsquared
vif_x4=1/(1-rsq_x4)
rsq_x5=smf.ols(formula='x5_latitude~x1_trans_date+x2_h_age+x3_MRT_dist+x4_stores+x6_longitude',data=data1).fit().rsquared
vif_x5=1/(1-rsq_x5)
rsq_x6=smf.ols(formula='x6_longitude~x1_trans_date+x2_h_age+x3_MRT_dist+x4_stores+x5_latitude',data=data1).fit().rsquared
vif_x6=1/(1-rsq_x6)

# %%
pd.DataFrame({'variables':['x1_trans_date','x2_h_age','x3_MRT_dist','x4_stores','x5_latitude','x6_longitude'],
              'VIF':[vif_x1,vif_x2,vif_x3,vif_x4,vif_x5,vif_x6]})
# Out:
#        variables       VIF
# 0  x1_trans_date  1.014674
# 1       x2_h_age  1.014287
# 2    x3_MRT_dist  4.323019
# 3      x4_stores  1.617038
# 4    x5_latitude  1.610234
# 5   x6_longitude  2.926302

# %% [markdown]
# ### Inference:
#    > **None** of the variables have **VIF>10**, So No collinearity we can **consider all variables** in Regression Equation

# %% [markdown]
# ## 5.Model Building

# %% [markdown]
# ### 5.1 Using Statsmodels

# %%
import statsmodels.formula.api as smf

# %%
model1= smf.ols('house_price~x1_trans_date+x2_h_age+x3_MRT_dist+x4_stores+x5_latitude+x6_longitude',data=data1).fit()
model1

# %%
#Finding intercepts and coefficients
model1.params
# Out:
# Intercept       -14437.100802
# x1_trans_date        5.146227
# x2_h_age            -0.269695
# x3_MRT_dist         -0.004487
# x4_stores            1.133277
# x5_latitude        225.472976
# x6_longitude       -12.423601
# dtype: float64

# %%
#Finding p-values & t-values
np.round(model1.pvalues,4), model1.tvalues
# Out:
# (Intercept        0.0337
#  x1_trans_date    0.0010
#  x2_h_age         0.0000
#  x3_MRT_dist      0.0000
#  x4_stores        0.0000
#  x5_latitude      0.0000
#  x6_longitude     0.7983
#  dtype: float64,
#  Intercept       -2.130726
#  x1_trans_date    3.305065
#  x2_h_age        -6.999504
#  x3_MRT_dist     -6.249708
#  x4_stores        6.022817
#  x5_latitude      5.059227
#  x6_longitude    -0.255724
#  dtype: float64)

# %% [markdown]
# ## Inference:
#    >As p-value of X6_longitude is greater than 0.5 (>0.5) there is no significance, and is significant value

# %% [markdown]
# ### The summary()
# The summary () method is used to obtain a table which gives an extensive description about the regression results

# %%
#Getting the summary of a model
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            house_price   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     94.59
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):           4.86e-74
# Time:                        14:36:57   Log-Likelihood:                -1487.0
# No. Observations:                 414   AIC:                             2988.
# Df Residuals:                     407   BIC:                             3016.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### NOTE:
# R-Squared is a measure of how well a linear regression model fits a dataset

# %% [markdown]
# ### Inference:
# >Here the R-Squared value is 58%

# %% [markdown]
# ## Checking for the outliers/Influencers:
# 1. Cooks Distance
# 2. Leverage Value(Influence plot)

# %%
(c,_)=model1.get_influence().cooks_distance
c
# Out:
# array([3.01372818e-03, 7.25729518e-04, 6.58583795e-05, 1.06900194e-03,
#        1.85206093e-04, 3.01127881e-05, 9.89020427e-05, 2.93395971e-07,
#        7.76293514e-03, 2.79303602e-03, 2.13288886e-03, 6.25378739e-04,
#        2.57582464e-05, 3.18187168e-04, 4.69210508e-03, 7.02579009e-03,
#        7.54765254e-03, 1.59214095e-06, 4.03438602e-04, 9.47296864e-07,
#        9.04534116e-04, 7.30599007e-05, 6.36434932e-04, 2.28177418e-08,
#        3.89628036e-04, 5.67918126e-04, 3.23220494e-03, 1.75842156e-03,
#        2.45119249e-04, 1.73732782e-03, 3.68259699e-03, 7.14428664e-03,
#        5.75631898e-04, 7.19199269e-05, 1.51669810e-03, 1.08016562e-02,
#        9.68493316e-04, 1.03368410e-03, 3.62176597e-04, 1.05807821e-06,
#        8.44836353e-05, 1.16653265e-04, 9.64924161e-05, 1.41684268e-03,
#        1.13642567e-03, 6.04354403e-05, 5.91249129e-04, 1.85092185e-02,
#        2.73054722e-05, 8.87586015e-04, 6.48584766e-05, 5.69628065e-04,
# ...

# %%
fig=plt.figure(figsize=(18,10))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.xlabel('Row Index',size= 15)
plt.ylabel('Cooks Distance',size =15)
plt.show()

# %%
np.argmax(c) , np.max(c)
# Out:
# (270, 0.19484937053727872)

# %%
#points beyond leverage cutoff value are influencer
from statsmodels.graphics.regressionplots import influence_plot
fig, ax = plt.subplots(figsize=(20,15))
fig = influence_plot(model1, ax=ax, criterion="cooks")

# %% [markdown]
# >So we observed **14 outliers/influencers** from both cooks distance and influence plot
# 35,113,126,344,249,187,285,148,270,271,220,228,312,389

# %%
#Dropping the influenced observations
data2=data1.drop([35,113,126,344,148,249,187,270,271,220,228,285,312,389],axis=0)
data2
# Out:
#       No  x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  x5_latitude  \
# 0      1       2012.917      32.0     84.87882         10     24.98298
# 1      2       2012.917      19.5    306.59470          9     24.98034
# 2      3       2013.583      13.3    561.98450          5     24.98746
# 3      4       2013.500      13.3    561.98450          5     24.98746
# 4      5       2012.833       5.0    390.56840          5     24.97937
# ..   ...            ...       ...          ...        ...          ...
# 409  410       2013.000      13.7   4082.01500          0     24.94155
# 410  411       2012.667       5.6     90.45606          9     24.97433
# 411  412       2013.250      18.8    390.96960          7     24.97923
# 412  413       2013.000       8.1    104.81010          5     24.96674
# 413  414       2013.500       6.5     90.45606          9     24.97433
#
#      x6_longitude  house_price
# 0       121.54024         37.9
# 1       121.53951         42.2
# ...

# %% [markdown]
# ### Model2 after removing outliers:

# %%
model2= smf.ols('house_price~x1_trans_date+x2_h_age+x3_MRT_dist+x4_stores+x5_latitude+x6_longitude',data=data2).fit()
model2

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            house_price   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     151.7
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):           4.81e-99
# Time:                        14:37:06   Log-Likelihood:                -1339.6
# No. Observations:                 400   AIC:                             2693.
# Df Residuals:                     393   BIC:                             2721.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Inference:
#    >R-squared value has increased from model1 - 58% to model2 69% after removing the influencers/Outliers

# %% [markdown]
# ### To increase the model Accuracy
# * **Applying log transformations**

# %%
log_x1=np.log((data2.x1_trans_date)+1)
log_x2=np.log((data2.x2_h_age)+1)
log_x3=np.log((data2.x3_MRT_dist)+1)
log_x4=np.log((data2.x4_stores)+1)
log_x5=np.log((data2.x5_latitude)+1)
log_x6=np.log((data2.x6_longitude)+1)

# %%
data2['log_x1']=log_x1
data2['log_x2']=log_x2
data2['log_x3']=log_x3
data2['log_x4']=log_x4
data2['log_x5']=log_x5
data2['log_x6']=log_x6

# %%
data2
# Out:
#       No  x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  x5_latitude  \
# 0      1       2012.917      32.0     84.87882         10     24.98298
# 1      2       2012.917      19.5    306.59470          9     24.98034
# 2      3       2013.583      13.3    561.98450          5     24.98746
# 3      4       2013.500      13.3    561.98450          5     24.98746
# 4      5       2012.833       5.0    390.56840          5     24.97937
# ..   ...            ...       ...          ...        ...          ...
# 409  410       2013.000      13.7   4082.01500          0     24.94155
# 410  411       2012.667       5.6     90.45606          9     24.97433
# 411  412       2013.250      18.8    390.96960          7     24.97923
# 412  413       2013.000       8.1    104.81010          5     24.96674
# 413  414       2013.500       6.5     90.45606          9     24.97433
#
#      x6_longitude  house_price    log_x1    log_x2    log_x3    log_x4  \
# ...

# %% [markdown]
# ### Model3 After Applying transformations

# %%
model3=smf.ols(formula='house_price~log_x1+log_x2+log_x3+log_x4+log_x5+log_x6',data=data2).fit()
model3

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            house_price   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     231.8
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):          9.91e-126
# Time:                        14:37:11   Log-Likelihood:                -1276.8
# No. Observations:                 400   AIC:                             2568.
# Df Residuals:                     393   BIC:                             2596.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.336e+05   2.21e+04     -6.049      0.000   -1.77e+05   -9.02e+04
# ...

# %% [markdown]
# ### Inference:
#    >The R-squared value has increased from model2 69% to model3 78%

# %%
data2.head()
# Out:
#    No  x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  x5_latitude  \
# 0   1       2012.917      32.0     84.87882         10     24.98298
# 1   2       2012.917      19.5    306.59470          9     24.98034
# 2   3       2013.583      13.3    561.98450          5     24.98746
# 3   4       2013.500      13.3    561.98450          5     24.98746
# 4   5       2012.833       5.0    390.56840          5     24.97937
#
#    x6_longitude  house_price    log_x1    log_x2    log_x3    log_x4  \
# 0     121.54024         37.9  7.607837  3.496508  4.452937  2.397895
# 1     121.53951         42.2  7.607837  3.020425  5.728783  2.302585
# 2     121.54391         47.3  7.608168  2.660260  6.333252  1.791759
# 3     121.54391         54.8  7.608126  2.660260  6.333252  1.791759
# 4     121.54245         43.1  7.607795  1.791759  5.970160  1.791759
#
#      log_x5    log_x6
# 0  3.257442  4.808439
# 1  3.257340  4.808434
# 2  3.257614  4.808469
# 3  3.257614  4.808469
# 4  3.257303  4.808458

# %%
#Dropping No feature
data2.drop(labels='No',axis=1,inplace=True)

# %%
data2.shape
# Out:
# (400, 13)

# %%
data2
# Out:
#      x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  x5_latitude  \
# 0         2012.917      32.0     84.87882         10     24.98298
# 1         2012.917      19.5    306.59470          9     24.98034
# 2         2013.583      13.3    561.98450          5     24.98746
# 3         2013.500      13.3    561.98450          5     24.98746
# 4         2012.833       5.0    390.56840          5     24.97937
# ..             ...       ...          ...        ...          ...
# 409       2013.000      13.7   4082.01500          0     24.94155
# 410       2012.667       5.6     90.45606          9     24.97433
# 411       2013.250      18.8    390.96960          7     24.97923
# 412       2013.000       8.1    104.81010          5     24.96674
# 413       2013.500       6.5     90.45606          9     24.97433
#
#      x6_longitude  house_price    log_x1    log_x2    log_x3    log_x4  \
# 0       121.54024         37.9  7.607837  3.496508  4.452937  2.397895
# ...

# %% [markdown]
# ### Standardizing the data:
# >To make different formatted data into similar scale

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()
scaled_data= scaler.fit_transform(data2)

# %%
scaled_data.shape
# Out:
# (400, 13)

# %%
print(scaled_data)
# Out:
# [[-0.80661614  1.27957977 -0.79365586 ...  1.31753423  1.17487719
#    0.44710901]
#  [-0.80661614  0.17577058 -0.6122608  ...  1.19151955  0.95525803
#    0.39875784]
#  [ 1.55149129 -0.37171879 -0.40331569 ...  0.51612969  1.54751319
#    0.69018522]
#  ...
#  [ 0.37243758  0.11395726 -0.54323016 ...  0.89648953  0.8629115
#    0.42193994]
#  [-0.51273789 -0.83090341 -0.77734925 ...  0.51612969 -0.17646711
#    0.47558971]
#  [ 1.25761304 -0.97219099 -0.78909289 ...  1.19151955  0.45520845
#    0.63653688]]

# %%
data2.columns
# Out:
# Index(['x1_trans_date', 'x2_h_age', 'x3_MRT_dist', 'x4_stores', 'x5_latitude',
#        'x6_longitude', 'house_price', 'log_x1', 'log_x2', 'log_x3', 'log_x4',
#        'log_x5', 'log_x6'],
#       dtype='object')

# %%
scaled_x_y=pd.DataFrame(data=scaled_data,columns=[ 'x1_trans_date', 'x2_h_age', 'x3_MRT_dist', 'x4_stores',
       'x5_latitude', 'x6_longitude', 'house_price', 'log_x1', 'log_x2',
       'log_x3', 'log_x4', 'log_x5', 'log_x6'])
scaled_x_y
# Out:
#      x1_trans_date  x2_h_age  x3_MRT_dist  x4_stores  x5_latitude  \
# 0        -0.806616  1.279580    -0.793656   2.019516     1.175129
# 1        -0.806616  0.175771    -0.612261   1.676352     0.955371
# 2         1.551491 -0.371719    -0.403316   0.303699     1.548052
# 3         1.257613 -0.371719    -0.403316   0.303699     1.548052
# 4        -1.104035 -1.104648    -0.543558   0.303699     0.874627
# ..             ...       ...          ...        ...          ...
# 395      -0.512738 -0.336397     2.476569  -1.412117    -2.273574
# 396      -1.691792 -1.051665    -0.789093   1.676352     0.455088
# 397       0.372438  0.113957    -0.543230   0.990026     0.862973
# 398      -0.512738 -0.830903    -0.777349   0.303699    -0.176716
# 399       1.257613 -0.972191    -0.789093   1.676352     0.455088
#
#      x6_longitude  house_price    log_x1    log_x2    log_x3    log_x4  \
# 0        0.447093     0.025348 -0.806584  0.969032 -1.741840  1.317534
# ...

# %% [markdown]
# ### Model4 After Standardizing the data

# %%
model4=smf.ols(formula='house_price~log_x1+log_x2+log_x3+log_x4+log_x5+log_x6',data=scaled_x_y).fit()
model4

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            house_price   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     231.8
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):          9.91e-126
# Time:                        14:37:21   Log-Likelihood:                -265.06
# No. Observations:                 400   AIC:                             544.1
# Df Residuals:                     393   BIC:                             572.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.201e-13      0.024   3.46e-11      1.000      -0.047       0.047
# ...

# %% [markdown]
# ### Inference:
#    >There is **no change** in the R-squared value from model3 78% to **model4 78%** even after applying standardization

# %% [markdown]
# ### Before Scaling:

# %%
#Mean
data2.mean()
# Out:
# x1_trans_date    2013.144813
# x2_h_age           17.509500
# x3_MRT_dist      1054.949925
# x4_stores           4.115000
# x5_latitude        24.968863
# x6_longitude      121.533491
# house_price        37.582000
# log_x1              7.607950
# log_x2              2.635732
# log_x3              6.378194
# log_x4              1.401389
# log_x5              3.256898
# log_x6              4.808384
# dtype: float64

# %%
#Standard Deviation
data2.std()
# Out:
# x1_trans_date       0.282784
# x2_h_age           11.338603
# x3_MRT_dist      1223.812506
# x4_stores           2.917714
# x5_latitude         0.012028
# x6_longitude        0.015115
# house_price        12.561170
# log_x1              0.000140
# log_x2              0.889397
# log_x3              1.106685
# log_x4              0.757289
# log_x5              0.000463
# log_x6              0.000123
# dtype: float64

# %% [markdown]
# ### After Scaling:

# %%
#Mean
scaled_x_y.mean()
# Out:
# x1_trans_date   -6.239137e-13
# x2_h_age         7.022161e-17
# x3_MRT_dist     -2.109424e-17
# x4_stores       -6.661338e-17
# x5_latitude      2.881861e-14
# x6_longitude    -1.223807e-13
# house_price     -7.438494e-17
# log_x1          -4.386230e-12
# log_x2          -3.383405e-16
# log_x3          -1.426637e-16
# log_x4          -8.659740e-17
# log_x5          -5.398984e-13
# log_x6          -2.577149e-12
# dtype: float64

# %%
#Standard Deviation
scaled_x_y.std()
# Out:
# x1_trans_date    1.001252
# x2_h_age         1.001252
# x3_MRT_dist      1.001252
# x4_stores        1.001252
# x5_latitude      1.001252
# x6_longitude     1.001252
# house_price      1.001252
# log_x1           1.001252
# log_x2           1.001252
# log_x3           1.001252
# log_x4           1.001252
# log_x5           1.001252
# log_x6           1.001252
# dtype: float64

# %% [markdown]
#  >So after scaling we have zero error

# %% [markdown]
# ### Predicting the data using model4

# %%
pred= model4.predict(data2)
pred.tail()
# Out:
# 409   -2.839872
# 410   -0.445345
# 411   -1.506685
# 412   -0.672922
# 413   -0.481825
# dtype: float64

# %% [markdown]
# ### Inference:
#    >Even though i got gud accuracy As my model is not giving appropriate predictions again I would like to build a linear model using sklearn linear regression

# %% [markdown]
# ## 5.2 Using sklearn Linear Model

# %% [markdown]
# ### 5.2.1 Splitting the data into x and y variables

# %%
x= scaled_x_y.iloc[:,7:]
x
# Out:
#        log_x1    log_x2    log_x3    log_x4    log_x5    log_x6
# 0   -0.806584  0.969032 -1.741840  1.317534  1.174877  0.447109
# 1   -0.806584  0.433074 -0.587543  1.191520  0.955258  0.398758
# 2    1.551378  0.027612 -0.040660  0.516130  1.547513  0.690185
# 3    1.257561  0.027612 -0.040660  0.516130  1.547513  0.690185
# 4   -1.104040 -0.950115 -0.369161  0.516130  0.874559  0.593485
# ..        ...       ...       ...       ...       ...       ...
# 395 -0.512681  0.058670  1.751919 -1.852851 -2.274222 -1.966165
# 396 -1.691906 -0.842818 -1.684913  1.191520  0.455208  0.636537
# 397  0.372495  0.393962 -0.368234  0.896490  0.862911  0.421940
# 398 -0.512681 -0.481217 -1.553015  0.516130 -0.176467  0.475590
# 399  1.257561 -0.698908 -1.684913  1.191520  0.455208  0.636537
#
# [400 rows x 6 columns]

# %%
y= scaled_x_y.iloc[:,6]
y
# Out:
# 0      0.025348
# 1      0.368101
# 2      0.774623
# 3      1.372449
# 4      0.439840
#          ...
# 395   -1.768130
# 396    0.989840
# 397    0.240565
# 398    1.189116
# 399    2.097811
# Name: house_price, Length: 400, dtype: float64

# %% [markdown]
# ### 5.2.2 Splitting the data into training and testing datasets

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=2)

# %% [markdown]
# ### 5.2.3 Model Building

# %%
#Building a linear model
from sklearn.linear_model import LinearRegression
linear_model=LinearRegression()

#Fitting the model using training datasets
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 5.2.3 Predicting the results

# %%
y_test_pred=linear_model.predict(x_test)
y_test_pred
# Out:
# array([ 0.89689716, -0.38141529, -1.91505651,  0.19234069, -1.12144602,
#        -0.6471146 ,  0.30634308, -1.84895055,  0.51307294,  0.40294386,
#        -0.67091936, -0.26310853, -0.94271725, -1.2398364 ,  0.84622972,
#         0.47074472,  0.35140026, -0.78344322, -0.61499668,  0.7399992 ,
#         1.08026272,  0.9966522 ,  1.1911757 ,  0.92463468, -0.19338667,
#        -1.26485246, -0.40040563,  0.75286957, -0.64727089,  1.1645075 ,
#         0.25577046, -0.0243161 , -0.14165578, -0.642982  ,  0.69097301,
#         0.41245275,  1.04361666,  0.65764242,  0.2312933 ,  0.00440712,
#        -0.38481407,  1.10148336,  0.46040944, -2.32694419, -0.77026594,
#         0.44062182, -0.10103788,  0.4209337 ,  0.11567986, -1.73764055,
#         0.38667939, -0.61477259,  0.42472511,  1.3932063 , -1.88759147,
#         0.47496481,  1.07482113,  1.96253525,  1.1157487 , -1.83646997,
#         0.09513782,  1.1645075 , -0.66103807, -0.88593299, -0.22942852,
# ...

# %%
y_test_pred=linear_model.predict(x_test)
y_test_pred
# Out:
# array([ 0.89689716, -0.38141529, -1.91505651,  0.19234069, -1.12144602,
#        -0.6471146 ,  0.30634308, -1.84895055,  0.51307294,  0.40294386,
#        -0.67091936, -0.26310853, -0.94271725, -1.2398364 ,  0.84622972,
#         0.47074472,  0.35140026, -0.78344322, -0.61499668,  0.7399992 ,
#         1.08026272,  0.9966522 ,  1.1911757 ,  0.92463468, -0.19338667,
#        -1.26485246, -0.40040563,  0.75286957, -0.64727089,  1.1645075 ,
#         0.25577046, -0.0243161 , -0.14165578, -0.642982  ,  0.69097301,
#         0.41245275,  1.04361666,  0.65764242,  0.2312933 ,  0.00440712,
#        -0.38481407,  1.10148336,  0.46040944, -2.32694419, -0.77026594,
#         0.44062182, -0.10103788,  0.4209337 ,  0.11567986, -1.73764055,
#         0.38667939, -0.61477259,  0.42472511,  1.3932063 , -1.88759147,
#         0.47496481,  1.07482113,  1.96253525,  1.1157487 , -1.83646997,
#         0.09513782,  1.1645075 , -0.66103807, -0.88593299, -0.22942852,
# ...

# %%
pd.DataFrame(y_test_pred,columns=['y_test_pred'])
# Out:
#     y_test_pred
# 0      0.896897
# 1     -0.381415
# 2     -1.915057
# 3      0.192341
# 4     -1.121446
# ..          ...
# 75     0.792402
# 76    -0.307536
# 77     1.167738
# 78    -0.059875
# 79     0.062959
#
# [80 rows x 1 columns]

# %%
linear_model.score(x_train,y_train)
# Out:
# 0.7881500232880432

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.7230175879743437

# %% [markdown]
# ### Applying Regularization techniques

# %%
from sklearn.linear_model import Ridge
ridge_model= Ridge(alpha=50, max_iter=100,tol=1)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=1)

# %%
ridge_model.score(x_train,y_train)
# Out:
# 0.7812546466209901

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.7295405205351331

# %%
y_pred= ridge_model.predict(x_test)
y_pred
# Out:
# array([ 0.78532805, -0.37939084, -1.80338863,  0.18260903, -1.0087518 ,
#        -0.61357581,  0.31175886, -1.75963834,  0.49906647,  0.41493719,
#        -0.62982625, -0.24800496, -0.86363442, -1.18759943,  0.82791734,
#         0.46934528,  0.33595152, -0.63310843, -0.49715696,  0.71458952,
#         0.9461807 ,  0.94088809,  1.15085818,  0.80769538, -0.15234247,
#        -1.2055164 , -0.3886326 ,  0.6962888 , -0.52734471,  0.89699573,
#         0.28218443,  0.04358962, -0.09524158, -0.58155591,  0.64980346,
#         0.42028953,  0.90429891,  0.62413152,  0.22633052,  0.05911023,
#        -0.36168553,  0.84553032,  0.3060345 , -2.22117155, -0.64355703,
#         0.29840662, -0.05746408,  0.27494333,  0.17180189, -1.68568594,
#         0.36896062, -0.56507498,  0.42043285,  1.18947795, -1.8251984 ,
#         0.49963775,  1.01065461,  1.69995726,  1.0062796 , -1.7962463 ,
#         0.12301253,  0.89699573, -0.61371023, -0.73720359, -0.13600646,
# ...

# %% [markdown]
# ## Evaluating model performance

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

MAE= mean_absolute_error(y_test, y_pred)
MSE= mean_squared_error(y_test, y_pred)
RMSE= np.sqrt(MSE)

# %% [markdown]
# ## 1. Mean Absolute Error(MAE)
#  MAE an error basically is the absolute difference between the actual or true values and the values that are predicted. Absolute difference means that if the result has a negative sign, it is ignored.
#  * **Hence, MAE = True values – Predicted values**

# %%
#Mean Absolute Error
MAE
# Out:
# 0.37980935288314405

# %% [markdown]
# ### Interpretation:
#    >The **MAE** value has been found to be **0.379.** So, lower values of MAE indicate better fit of data.

# %% [markdown]
# ## 2. Mean Squared Error(MSE):
# MSE is calculated by taking the average of the square of the difference between the original and predicted values of the data.

# %% [markdown]
# ![1561476739-55378.png](attachment:1561476739-55378.png)

# %%
#Mean Squared Error
MSE
# Out:
# 0.22007076019888716

# %% [markdown]
# ### Interpretation:
#    >The **MSE** value has been found to be **0.220.** So, lower values of MSE indicate better fit of data.

# %% [markdown]
# ## 3. Root Mean Squared Error(RMSE):
# RMSE stands for Root Mean Square Error. RMSE is the standard deviation of the residuals. RMSE gives us the standard deviation of the unexplained variance by the model. It can be calculated by taking square root of Mean Squared Error.
#
# * The more concentrated the data is around the regression line, the lower the residuals and hence lower the standard deviation of residuals

# %%
#Root mean Squared error
RMSE
# Out:
# 0.4691170005434542

# %% [markdown]
# ### Interpretation:
# >The **RMSE** value has been found to be **0.469**. So, lower values of RMSE indicate better fit of data.

# %% [markdown]
# ## Deployment:

# %%
import pickle

# %%
with open("realestate.pkl",'wb') as f:
    pickle.dump(y_pred,f)
